# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/electric_vehicles_spec_2025.csv.csv")

# %%
df.head()
# Out:
#     brand                model  top_speed_kmh  battery_capacity_kWh  \
# 0  Abarth     500e Convertible            155                  37.8
# 1  Abarth       500e Hatchback            155                  37.8
# 2  Abarth  600e Scorpionissima            200                  50.8
# 3  Abarth         600e Turismo            200                  50.8
# 4  Aiways                   U5            150                  60.0
#
#   battery_type  number_of_cells  torque_nm  efficiency_wh_per_km  range_km  \
# 0  Lithium-ion            192.0      235.0                   156       225
# 1  Lithium-ion            192.0      235.0                   149       225
# 2  Lithium-ion            102.0      345.0                   158       280
# 3  Lithium-ion            102.0      345.0                   158       280
# 4  Lithium-ion              NaN      310.0                   156       315
#
#    acceleration_0_100_s  ...  towing_capacity_kg cargo_volume_l  seats  \
# ...

# %%
df.shape
# Out:
# (478, 22)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 478 entries, 0 to 477
# Data columns (total 22 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   brand                      478 non-null    object
#  1   model                      477 non-null    object
#  2   top_speed_kmh              478 non-null    int64
#  3   battery_capacity_kWh       478 non-null    float64
#  4   battery_type               478 non-null    object
#  5   number_of_cells            276 non-null    float64
#  6   torque_nm                  471 non-null    float64
#  7   efficiency_wh_per_km       478 non-null    int64
#  8   range_km                   478 non-null    int64
#  9   acceleration_0_100_s       478 non-null    float64
#  10  fast_charging_power_kw_dc  477 non-null    float64
#  11  fast_charge_port           477 non-null    object
#  12  towing_capacity_kg         452 non-null    float64
# ...

# %%
df.isnull().sum()
# Out:
# brand                          0
# model                          1
# top_speed_kmh                  0
# battery_capacity_kWh           0
# battery_type                   0
# number_of_cells              202
# torque_nm                      7
# efficiency_wh_per_km           0
# range_km                       0
# acceleration_0_100_s           0
# fast_charging_power_kw_dc      1
# fast_charge_port               1
# towing_capacity_kg            26
# cargo_volume_l                 1
# seats                          0
# drivetrain                     0
# segment                        0
# length_mm                      0
# width_mm                       0
# height_mm                      0
# car_body_type                  0
# source_url                     0
# dtype: int64

# %%
df[df['model'].isnull()]
# Out:
#        brand model  top_speed_kmh  battery_capacity_kWh battery_type  \
# 477  firefly   NaN            150                  41.2  Lithium-ion
#
#      number_of_cells  torque_nm  efficiency_wh_per_km  range_km  \
# 477            112.0      200.0                   125       250
#
#      acceleration_0_100_s  ...  towing_capacity_kg cargo_volume_l  seats  \
# 477                   8.1  ...                 0.0            404      5
#
#     drivetrain      segment length_mm width_mm  height_mm  car_body_type  \
# 477        RWD  B - Compact      4003     1885       1557      Hatchback
#
#                                            source_url
# 477  https://ev-database.org/car/3178/firefly-firefly
#
# [1 rows x 22 columns]

# %%
df = df[df['model'].notna()]

# %%
df.shape
# Out:
# (477, 22)

# %%
df['number_of_cells'].unique()
# Out:
# array([ 192.,  102.,   nan,  184.,  150.,  180.,  216.,  288.,  396.,
#         126.,  104.,   94.,   90.,  128.,  172.,  132.,  160.,  324.,
#          72.,  108.,  376.,  384.,  264.,  432.,  348.,  456.,   96.,
#        6600., 5400.,  300.,  360.,  118.,  204.,  110.,   93., 4416.,
#        7920.,  312.])

# %%
df['number_of_cells'] = df['number_of_cells'].fillna(df['number_of_cells'].median())

# %%
df['torque_nm'].unique()
# Out:
# array([ 235.,  345.,  310.,  315.,  260.,  285.,  300.,  435.,  565.,
#         855.,  545.,  679.,  450.,  485.,  865., 1027.,  740.,  625.,
#         795.,  400.,  430.,  600.,  590., 1100.,  650.,  745., 1015.,
#         700.,  765.,  247.,  494.,  290.,  180.,   nan,  175.,  220.,
#         380.,  670.,  360.,  330.,  690.,  610.,  120.,  125.,  511.,
#         113.,  160.,  320.,  122.,  675.,  525.,  950.,  415.,  250.,
#         680.,  340.,  350.,  605.,  750.,  147.,  255.,  696.,  339.,
#         283.,  770.,  158.,  266.,  710.,  985., 1200.,  343.,  725.,
#         475.,  280., 1350.,  820.,  335.,  515.,  385.,  390.,  520.,
#         550.,  858., 1000.,  800.,  568.,  828., 1020.,  245.,  365.,
#        1164.,  850.,  270.,  490.,  840.,  910.,  686.,  563., 1001.,
#         410.,  585.,  695.,  790.,  420.,  940., 1340., 1110.,  225.,
#         215.,  900.,  584.,  543.,  373.,  643.,  336.,  493.,  741.,
# ...

# %%
df['torque_nm'] = df['torque_nm'].fillna(df['torque_nm'].mean(), axis=0)

# %%
df.isnull().sum()
# Out:
# brand                         0
# model                         0
# top_speed_kmh                 0
# battery_capacity_kWh          0
# battery_type                  0
# number_of_cells               0
# torque_nm                     0
# efficiency_wh_per_km          0
# range_km                      0
# acceleration_0_100_s          0
# fast_charging_power_kw_dc     1
# fast_charge_port              1
# towing_capacity_kg           26
# cargo_volume_l                1
# seats                         0
# drivetrain                    0
# segment                       0
# length_mm                     0
# width_mm                      0
# height_mm                     0
# car_body_type                 0
# source_url                    0
# dtype: int64

# %%
df[df['fast_charging_power_kw_dc'].isnull()]
# Out:
#        brand                model  top_speed_kmh  battery_capacity_kWh  \
# 356  Renault  5 E-Tech 40kWh 95hp            130                  40.0
#
#     battery_type  number_of_cells  torque_nm  efficiency_wh_per_km  range_km  \
# 356  Lithium-ion             93.0      215.0                   129       255
#
#      acceleration_0_100_s  ...  towing_capacity_kg cargo_volume_l  seats  \
# 356                  12.0  ...               500.0            326      5
#
#     drivetrain      segment length_mm width_mm  height_mm  car_body_type  \
# 356        FWD  B - Compact      3922     1808       1489      Hatchback
#
#                                             source_url
# 356  https://ev-database.org/car/2133/Renault-5-E-T...
#
# [1 rows x 22 columns]

# %%
df = df.drop(index=356, axis=0)

# %%
df.isnull().sum()
# Out:
# brand                         0
# model                         0
# top_speed_kmh                 0
# battery_capacity_kWh          0
# battery_type                  0
# number_of_cells               0
# torque_nm                     0
# efficiency_wh_per_km          0
# range_km                      0
# acceleration_0_100_s          0
# fast_charging_power_kw_dc     0
# fast_charge_port              0
# towing_capacity_kg           26
# cargo_volume_l                1
# seats                         0
# drivetrain                    0
# segment                       0
# length_mm                     0
# width_mm                      0
# height_mm                     0
# car_body_type                 0
# source_url                    0
# dtype: int64

# %%
df['towing_capacity_kg'].unique()
# Out:
# array([   0.,   nan,  500., 2100., 1000., 1200., 2000., 2400., 1600.,
#        1500., 2500.,  750., 1300., 1587.,  550.,  350., 1400., 1260.,
#        1800.,  300.,  900., 2250., 1225., 1700., 1250., 2200., 1100.])

# %%
df[df['towing_capacity_kg'].isnull()].head()
# Out:
#         brand         model  top_speed_kmh  battery_capacity_kWh battery_type  \
# 4      Aiways            U5            150                  60.0  Lithium-ion
# 5      Aiways            U6            160                  60.0  Lithium-ion
# 100  Dongfeng  Box 31.4 kWh            140                  29.0  Lithium-ion
# 101  Dongfeng  Box 42.3 kWh            140                  40.0  Lithium-ion
# 102    Elaris    BEO 86 kWh            150                  81.0  Lithium-ion
#
#      number_of_cells  torque_nm  efficiency_wh_per_km  range_km  \
# 4              216.0      310.0                   156       315
# 5              216.0      315.0                   150       350
# 100            216.0      160.0                   126       190
# 101            216.0      160.0                   129       255
# 102            216.0      320.0                   203       390
#
#      acceleration_0_100_s  ...  towing_capacity_kg cargo_volume_l  seats  \
# ...

# %%
condition = (df['towing_capacity_kg'] == 0) | (df['towing_capacity_kg'].isna())
count = condition.sum()
print(count)
# Out:
# 131

# %%
df['towing_capacity_kg'] = df['towing_capacity_kg'].replace(0,np.nan)

# %%
df['towing_capacity_kg'].isna().sum()
# Out:
# np.int64(131)

# %%
df['towing_capacity_kg'] = df['towing_capacity_kg'].fillna(df['towing_capacity_kg'].mean(),axis=0)

# %%
df.isna().sum()
# Out:
# brand                        0
# model                        0
# top_speed_kmh                0
# battery_capacity_kWh         0
# battery_type                 0
# number_of_cells              0
# torque_nm                    0
# efficiency_wh_per_km         0
# range_km                     0
# acceleration_0_100_s         0
# fast_charging_power_kw_dc    0
# fast_charge_port             0
# towing_capacity_kg           0
# cargo_volume_l               1
# seats                        0
# drivetrain                   0
# segment                      0
# length_mm                    0
# width_mm                     0
# height_mm                    0
# car_body_type                0
# source_url                   0
# dtype: int64

# %%
df[df['cargo_volume_l'].isnull()]
# Out:
#     brand              model  top_speed_kmh  battery_capacity_kWh  \
# 128  Ford  e-Tourneo Courier            145                  43.6
#
#     battery_type  number_of_cells  torque_nm  efficiency_wh_per_km  range_km  \
# 128  Lithium-ion            216.0      290.0                   164       200
#
#      acceleration_0_100_s  ...  towing_capacity_kg cargo_volume_l  seats  \
# 128                  11.0  ...               750.0            NaN      5
#
#     drivetrain            segment length_mm width_mm  height_mm  \
# 128        FWD  N - Passenger Van      4337     1876       1817
#
#            car_body_type                                         source_url
# 128  Small Passenger Van  https://ev-database.org/car/3166/Ford-e-Tourne...
#
# [1 rows x 22 columns]

# %%
df = df.drop(index=128,axis=0)

# %%
df.shape
# Out:
# (475, 22)

# %%
df.describe()
# Out:
#        top_speed_kmh  battery_capacity_kWh  number_of_cells    torque_nm  \
# count     475.000000            475.000000       475.000000   475.000000
# mean      185.764211             74.248632       372.951579   499.683216
# std        34.175879             20.229923       931.698526   239.501655
# min       125.000000             21.300000        72.000000   113.000000
# 25%       160.000000             60.000000       216.000000   310.000000
# 50%       180.000000             77.000000       216.000000   440.000000
# 75%       201.000000             90.600000       288.000000   679.000000
# max       325.000000            118.000000      7920.000000  1350.000000
#
#        efficiency_wh_per_km    range_km  acceleration_0_100_s  \
# count            475.000000  475.000000            475.000000
# mean             163.052632  394.178947              6.860632
# std               34.346266  102.822815              2.721997
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 475 entries, 0 to 476
# Data columns (total 22 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   brand                      475 non-null    object
#  1   model                      475 non-null    object
#  2   top_speed_kmh              475 non-null    int64
#  3   battery_capacity_kWh       475 non-null    float64
#  4   battery_type               475 non-null    object
#  5   number_of_cells            475 non-null    float64
#  6   torque_nm                  475 non-null    float64
#  7   efficiency_wh_per_km       475 non-null    int64
#  8   range_km                   475 non-null    int64
#  9   acceleration_0_100_s       475 non-null    float64
#  10  fast_charging_power_kw_dc  475 non-null    float64
#  11  fast_charge_port           475 non-null    object
#  12  towing_capacity_kg         475 non-null    float64
# ...

# %%
df['cargo_volume_l'].unique()
# Out:
# array(['185', '360', '496', '472', '400', '326', '502', '520', '535',
#        '526', '511', '10 Banana Boxes', '514', '350', '405', '470', '490',
#        '570', '500', '525', '440', '345', '308', '552', '235', '385',
#        '540', '793', '775', '1050', '310', '460', '380', '510', '603',
#        '989', '390', '620', '467', '361', '572', '536', '519', '523',
#        '672', '228', '333', '354', '432', '503', '438', '280', '480',
#        '401', '338', '466', '505', '355', '550', '839', '435', '475',
#        '309', '210', '522', '316', '611', '509', '456', '410', '249',
#        '363', '479', '453', '448', '151', '270', '31 Banana Boxes', '340',
#        '495', '430', '645', '13 Banana Boxes', '828', '551', '1410',
#        '1030', '555', '1390', '990', '300', '200', '579', '265', '386',
#        '450', '468', '415', '819', '352', '516', '267', '434', '588',
#        '412', '608', '471', '348', '407', '484', '446', '366', '367',
# ...

# %%
df['cargo_volume_l'] = df['cargo_volume_l'].replace(' Banana Boxes','', regex=True)

# %%
df['cargo_volume_l'].unique()
# Out:
# array(['185', '360', '496', '472', '400', '326', '502', '520', '535',
#        '526', '511', '10', '514', '350', '405', '470', '490', '570',
#        '500', '525', '440', '345', '308', '552', '235', '385', '540',
#        '793', '775', '1050', '310', '460', '380', '510', '603', '989',
#        '390', '620', '467', '361', '572', '536', '519', '523', '672',
#        '228', '333', '354', '432', '503', '438', '280', '480', '401',
#        '338', '466', '505', '355', '550', '839', '435', '475', '309',
#        '210', '522', '316', '611', '509', '456', '410', '249', '363',
#        '479', '453', '448', '151', '270', '31', '340', '495', '430',
#        '645', '13', '828', '551', '1410', '1030', '555', '1390', '990',
#        '300', '200', '579', '265', '386', '450', '468', '415', '819',
#        '352', '516', '267', '434', '588', '412', '608', '471', '348',
#        '407', '484', '446', '366', '367', '420', '950', '545', '585',
# ...

# %%
df.columns
# Out:
# Index(['brand', 'model', 'top_speed_kmh', 'battery_capacity_kWh',
#        'battery_type', 'number_of_cells', 'torque_nm', 'efficiency_wh_per_km',
#        'range_km', 'acceleration_0_100_s', 'fast_charging_power_kw_dc',
#        'fast_charge_port', 'towing_capacity_kg', 'cargo_volume_l', 'seats',
#        'drivetrain', 'segment', 'length_mm', 'width_mm', 'height_mm',
#        'car_body_type', 'source_url'],
#       dtype='object')

# %%
df.head()
# Out:
#     brand                model  top_speed_kmh  battery_capacity_kWh  \
# 0  Abarth     500e Convertible            155                  37.8
# 1  Abarth       500e Hatchback            155                  37.8
# 2  Abarth  600e Scorpionissima            200                  50.8
# 3  Abarth         600e Turismo            200                  50.8
# 4  Aiways                   U5            150                  60.0
#
#   battery_type  number_of_cells  torque_nm  efficiency_wh_per_km  range_km  \
# 0  Lithium-ion            192.0      235.0                   156       225
# 1  Lithium-ion            192.0      235.0                   149       225
# 2  Lithium-ion            102.0      345.0                   158       280
# 3  Lithium-ion            102.0      345.0                   158       280
# 4  Lithium-ion            216.0      310.0                   156       315
#
#    acceleration_0_100_s  ...  towing_capacity_kg cargo_volume_l  seats  \
# ...

# %%
df_models = df.drop(['model','battery_type','segment','source_url'],axis = 1)

# %%
df_models.head()
# Out:
#     brand  top_speed_kmh  battery_capacity_kWh  number_of_cells  torque_nm  \
# 0  Abarth            155                  37.8            192.0      235.0
# 1  Abarth            155                  37.8            192.0      235.0
# 2  Abarth            200                  50.8            102.0      345.0
# 3  Abarth            200                  50.8            102.0      345.0
# 4  Aiways            150                  60.0            216.0      310.0
#
#    efficiency_wh_per_km  range_km  acceleration_0_100_s  \
# 0                   156       225                   7.0
# 1                   149       225                   7.0
# 2                   158       280                   5.9
# 3                   158       280                   6.2
# 4                   156       315                   7.5
#
#    fast_charging_power_kw_dc fast_charge_port  towing_capacity_kg  \
# 0                       67.0              CCS         1377.165217
# ...

# %%
df['brand'].value_counts()
# Out:
# brand
# Mercedes-Benz    42
# Audi             28
# Porsche          26
# Volkswagen       23
# Ford             21
# BMW              20
# Peugeot          19
# Volvo            18
# Smart            17
# BYD              17
# Kia              16
# Opel             14
# Hyundai          14
# MG               12
# Citroen          12
# NIO              12
# Skoda            12
# Tesla            11
# Renault          10
# XPENG             9
# Zeekr             9
# Polestar          9
# Mini              8
# Fiat              8
# Toyota            7
# GWM               6
# Lotus             6
# Nissan            6
# CUPRA             5
# Genesis           5
# DS                5
# Abarth            4
# Lucid             3
# Lexus             3
# Hongqi            3
# Maserati          3
# Alfa              2
# Dacia             2
# Aiways            2
# Alpine            2
# Dongfeng          2
# Jeep              2
# VinFast           2
# Skywell           2
# Leapmotor         2
# ...

# %% [markdown]
# Linear Regression

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %%
cols_to_encode = ['brand','fast_charge_port','drivetrain','car_body_type']
for col in cols_to_encode:
    encoder = LabelEncoder()
    df_models[col] = encoder.fit_transform(df_models[col])

# %%
X = df_models.drop('range_km',axis = 1)
y = df['range_km']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= 0.2, random_state=15)

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
linear = LinearRegression()
linear.fit(X_train_scaled,y_train)
y_pred = linear.predict(X_test_scaled)
score = r2_score(y_test,y_pred)
mae = mean_absolute_error(y_test,y_pred)
mse = mean_squared_error(y_test,y_pred)
print(f"R2 score: {score}, MAE: {mae}, MSE: {mse}")

plt.figure(figsize=(10,6))
plt.scatter(y_pred,y_test,marker = 'o',edgecolors='k',alpha=0.6)
plt.plot([y_test.min(),y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=3)
plt.xlabel('Predicted Range (km)')
plt.ylabel('Actual Range (km)')
plt.title('Actual vs Predicted Range')
plt.grid(True)
plt.show()
# Out:
# R2 score: 0.941112753423949, MAE: 19.03424174696529, MSE: 590.3056606314716

# %% [markdown]
# Support Vector Regressor (SVR)

# %%
from sklearn.svm import SVR

# %%
model = SVR()

# %%
model.fit(X_train_scaled,y_train)
y_pred = model.predict(X_test_scaled)
score = r2_score(y_test,y_pred)
mae = mean_absolute_error(y_test,y_pred)
mse = mean_squared_error(y_test,y_pred)
print(f"R2 score: {score}, MAE: {mae}, MSE: {mse}")

plt.figure(figsize=(10,6))
plt.scatter(y_pred, y_test, marker = 'o', edgecolors='k', alpha=0.6)
plt.plot([y_test.min(),y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=3)
plt.xlabel('Predicted Range (km)')
plt.ylabel('Actual Range (km)')
plt.title('Actual vs Predicted Range')
plt.grid(True)
plt.show()
# Out:
# R2 score: 0.2625134739185341, MAE: 69.61414752880702, MSE: 7392.814171114249

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {
    'C' : [1000 ,100, 10, 1, 0.1, 0.01],
    'kernel' : ['rbf','linear', 'poly'],
    'gamma' : ['scale','auto'],
    'epsilon' : [0.01, 0.1, 0.2, 0.5]
}

# %%
grid = GridSearchCV(estimator=SVR(),param_grid=param_grid, cv=5, n_jobs=-1, scoring='r2')

# %%
grid.fit(X_train_scaled,y_train)
# Out:
# GridSearchCV(cv=5, estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [1000, 100, 10, 1, 0.1, 0.01],
#                          'epsilon': [0.01, 0.1, 0.2, 0.5],
#                          'gamma': ['scale', 'auto'],
#                          'kernel': ['rbf', 'linear', 'poly']},
#              scoring='r2')

# %%
y_pred = grid.predict(X_test_scaled)
score = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
print(f"R2 score: {score}, MAE: {mae}, MSE: {mse}")

plt.figure(figsize=(10,6))
plt.scatter(y_pred, y_test, color='r', marker = 'o', edgecolors='k', alpha=0.6)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=3)
plt.xlabel('Predicted Range (km)')
plt.ylabel('Actual Range (km)')
plt.title('Actual vs Predicted Range')
plt.grid(True)
plt.show()
# Out:
# R2 score: 0.9803027541109908, MAE: 10.450015885639024, MSE: 197.45184947840454

# %%
grid.best_params_
# Out:
# {'C': 1000, 'epsilon': 0.5, 'gamma': 'auto', 'kernel': 'rbf'}

# %% [markdown]
# K-Nearest Neighbour (KNN) Regressor

# %%
from sklearn.neighbors import KNeighborsRegressor
knn_regressor = KNeighborsRegressor(n_neighbors=5, algorithm='auto')

# %%
knn_regressor.fit(X_train_scaled,y_train)
# Out:
# KNeighborsRegressor()

# %%
y_pred = knn_regressor.predict(X_test_scaled)
score = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
print(f"R2 score: {score}, MAE: {mae}, MSE: {mse}")

plt.figure(figsize=(10,6))
plt.scatter(y_pred, y_test, color='r', marker = 'o', edgecolors='k', alpha=0.6)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=3)
plt.xlabel('Predicted Range (km)')
plt.ylabel('Actual Range (km)')
plt.title('Actual vs Predicted Range')
plt.grid(True)
plt.show()
# Out:
# R2 score: 0.804383458983206, MAE: 34.88421052631579, MSE: 1960.9263157894736

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
params = {
    'algorithm' : ['kd_tree','auto','ball_tree'],
    'n_neighbors' : [100, 10, 20, 1, 0.1, 0.01],
    'weights' : ['uniform','distance'],
    'p': [1.1, 1,25, 1.5, 1.75, 1.85, 1.95]
}

# %%
random_model = RandomizedSearchCV(estimator=KNeighborsRegressor(), param_distributions=params, n_jobs= -1, cv=5, scoring='r2', verbose=3 )

# %%
random_model.fit(X_train_scaled,y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py:528: FitFailedWarning:
# 10 fits failed out of a total of 50.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 10 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/base.py", line 1382, in wrapper
#     estimator._validate_params()
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/base.py", line 436, in _validate_params
# ...

# %%
y_pred = random_model.predict(X_test_scaled)
score = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
print(f"R2 score: {score}, MAE: {mae}, MSE: {mse}")

plt.figure(figsize=(10,6))
plt.scatter(y_pred, y_test, color='g', marker = 'o', edgecolors='k', alpha=0.6)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=3)
plt.xlabel('Predicted Range (km)')
plt.ylabel('Actual Range (km)')
plt.title('Actual vs Predicted Range')
plt.grid(True)
plt.show()
# Out:
# R2 score: 0.8520806425286324, MAE: 27.8770112468661, MSE: 1482.7936286603342

# %%
random_model.best_params_
# Out:
# {'weights': 'distance', 'p': 1.5, 'n_neighbors': 10, 'algorithm': 'ball_tree'}

# %% [markdown]
# Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
tree_model = DecisionTreeRegressor()

# %%
tree_model.fit(X_train_scaled, y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred = tree_model.predict(X_test_scaled)
score = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
print(f"R2 score: {score}, MAE: {mae}, MSE: {mse}")

plt.figure(figsize=(10,6))
plt.scatter(y_pred, y_test, color='g', marker = 'o', edgecolors='k', alpha=0.6)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=3)
plt.xlabel('Predicted Range (km)')
plt.ylabel('Actual Range (km)')
plt.title('Actual vs Predicted Range')
plt.grid(True)
plt.show()
# Out:
# R2 score: 0.9141366054804014, MAE: 19.92105263157895, MSE: 860.7236842105264

# %%
from sklearn import tree

plt.figure(figsize=(20,10))
tree.plot_tree(tree_model, filled=True)
plt.show()

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {
    'criterion' : ['squared_error','absolute_error','friedman_mse'],
    'splitter' : ['best','random'],
    'max_depth' : [1,2,5,10,20],
    'min_samples_leaf' : [1,3,5]
}

# %%
grid = GridSearchCV(estimator=DecisionTreeRegressor(), param_grid=param_grid, cv=5, n_jobs=-1,scoring='r2')

# %%
grid.fit(X_train_scaled,y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse'],
#                          'max_depth': [1, 2, 5, 10, 20],
#                          'min_samples_leaf': [1, 3, 5],
#                          'splitter': ['best', 'random']},
#              scoring='r2')

# %%
y_pred = grid.predict(X_test_scaled)
score = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
print(f"R2 score: {score}, MAE: {mae}, MSE: {mse}")

plt.figure(figsize=(10,6))
plt.scatter(y_pred, y_test, color='g', marker = 'o', edgecolors='k', alpha=0.6)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=3)
plt.xlabel('Predicted Range (km)')
plt.ylabel('Actual Range (km)')
plt.title('Actual vs Predicted Range')
plt.grid(True)
plt.show()
# Out:
# R2 score: 0.9142613019946468, MAE: 19.68421052631579, MSE: 859.4736842105264

# %%
grid.best_params_
# Out:
# {'criterion': 'squared_error',
#  'max_depth': 20,
#  'min_samples_leaf': 1,
#  'splitter': 'best'}
